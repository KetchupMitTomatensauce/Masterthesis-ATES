# %%
from nbclient import NotebookClient
from nbformat import read, NO_CONVERT

# import userinput
# if userinput.LT_ATES:
#     path_I = "LT_Analysis_II_A.ipynb"
#     path_II = "LT_Analysis_II_SetCap.ipynb"
# else:
path_I = "Analysis_II_A.ipynb"
path_II = "Analysis_II_SetCap.ipynb"


with open(path_I) as f:
    nb = read(f, as_version=NO_CONVERT)

client = NotebookClient(nb)
client.execute()

with open(path_II) as f:
    nb = read(f, as_version=NO_CONVERT)

client = NotebookClient(nb)
client.execute()
# Out:
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'f2001e2b',
#    'metadata': {'execution': {'iopub.status.busy': '2025-09-02T13:33:12.421973Z',
#      'iopub.execute_input': '2025-09-02T13:33:12.421973Z',
#      'shell.execute_reply': '2025-09-02T13:33:13.428447Z',
#      'iopub.status.idle': '2025-09-02T13:33:13.428987Z'}},
#    'outputs': [],
#    'source': 'import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport userinput\nfrom IPython.display import clear_output\n'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'id': '8f8bc509',
#    'metadata': {'execution': {'iopub.status.busy': '2025-09-02T13:33:13.428987Z',
#      'iopub.execute_input': '2025-09-02T13:33:13.428987Z',
#      'shell.execute_reply': '2025-09-02T13:33:13.452757Z',
#      'iopub.status.idle': '2025-09-02T13:33:13.453315Z'}},
#    'outputs': [],
#    'source': 'df_temp_time = pd.read_csv(\'csv_and_xlsx/Analysis_I_temp_time.csv\')\n\ntime_index_H = pd.date_range(start=str(userinput.year_input) +"-01-01 00:00", end=str(userinput.year_input) +"-12-31  23:00", freq="H")\ntemperature_heat = pd.Series(df_temp_time[\'temperature_heat\'].values, index=time_index_H)\nheat_demand = pd.Series(df_temp_time[\'heat_demand\'].values, index=time_index_H)\nCOP_hp = pd.Series(df_temp_time[\'COP_hp\'].values, index=time_index_H)\nelectricity_price = pd.Series(df_temp_time[\'electricity_price\'].values, index=time_index_H)'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'id': '2ed63e4f',
#    'metadata': {'execution': {'iopub.status.busy': '2025-09-02T13:33:13.455095Z',
#      'iopub.execute_input': '2025-09-02T13:33:13.455095Z',
#      'shell.execute_reply': '2025-09-02T13:33:13.466578Z',
#      'iopub.status.idle': '2025-09-02T13:33:13.466578Z'}},
#    'outputs': [],
#    'source': 'df_Analysis_I = pd.read_csv("csv_and_xlsx/ATES_sensitivity_results_I.csv")\nif userinput.Depth_drilling_possible:\n    pass\nelse:\n    df_Analysis_I = df_Analysis_I[df_Analysis_I[\'depth_ATES\'] == df_Analysis_I[\'depth_ATES\'].min()]\n\n\nfirst_row = df_Analysis_I.iloc[[0]]\nmax_phi_row = df_Analysis_I.loc[[df_Analysis_I[\'phi_charge\'].idxmax()]]\nmin_phi_row = df_Analysis_I.loc[[df_Analysis_I[\'phi_charge\'].idxmin()]]\n\ndf_Analysis_II = pd.concat([first_row, max_phi_row, min_phi_row]).drop_duplicates().reset_index(drop=True)'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'id': '56ffefe9',
#    'metadata': {'execution': {'iopub.status.busy': '2025-09-02T13:33:13.466578Z',
#      'iopub.execute_input': '2025-09-02T13:33:13.466578Z',
#      'iopub.status.idle': '2025-09-02T14:10:06.750740Z',
#      'shell.execute_reply': '2025-09-02T14:10:06.750740Z'}},
#    'outputs': [],
#    'source': 'import os\nfrom ATES_optimization import optimization\n\n# Define the ranges for each variable\nphi_c_range = df_Analysis_II[\'phi_charge\'].values\nelpr_range = np.array(userinput.elpr_range)\ndrc_range = np.array(userinput.drc_range)\nCapTT_range = np.array(userinput.CapTT_range) \n\nif userinput.Depth_drilling_possible:\n    os.makedirs("optimization_2_results_capmax_depth", exist_ok=True)\n    # Delete all files in the directory\n    for f in os.listdir("optimization_2_results_capmax_depth"):\n        file_path = os.path.join("optimization_2_results_capmax_depth", f)\n        if os.path.isfile(file_path):\n            os.remove(file_path)\nelse:\n    os.makedirs("optimization_2_results_capmax", exist_ok=True)\n    # Delete all files in the directory\n    for f in os.listdir("optimization_2_results_capmax"):\n        file_path = os.path.join("optimization_2_results_capmax", f)\n        if os.path.isfile(file_path):\n            os.remove(file_path)\n\nfor phi_c in phi_c_range:\n    for elpr in elpr_range:\n        for drc in drc_range:\n            for CapTT in CapTT_range:\n                # Run the optimization with the current parameters\n                df_aux = df_Analysis_II[df_Analysis_II[\'phi_charge\'] == phi_c]\n                m, obj_sol = optimization(df_aux.depth_ATES.iloc[0], df_aux.ATES_max_power.iloc[0], time_index_H, temperature_heat,df_aux.phi_standing.iloc[0],\n                                    df_aux.phi_charge.iloc[0], heat_demand, df_aux.P_pump.iloc[0], COP_hp, elpr * electricity_price, drilling_costs=drc * userinput.drilling_costs, Capex_TTES=CapTT * userinput.Capex_TTES, interest=userinput.interest, power_ATES_min=df_Analysis_I[\'ATES_max_power\'].iloc[0]\n                                )\n                # Collect all results from m.solution and m.dual in a DataFrame\n                # Combine m.solution and m.dual into a single DataFrame with matching datetime index\n                m_solution = pd.DataFrame({k: v.values for k, v in m.solution.data_vars.items()}, index=time_index_H)\n                m_dual = pd.DataFrame({k: v.values for k, v in m.dual.data_vars.items()}, index=time_index_H)\n                system_info = pd.DataFrame({\n                    \'phi_charge\': [phi_c],\n                    \'phi_standing\': [df_Analysis_II[df_Analysis_II[\'phi_charge\'] == phi_c][\'phi_standing\'].values[0]],\n                    #\'heat_demand\': [heat_demand.values],\n                    \'electricity_price\': [elpr],\n                    \'drilling_costs\': [drc * userinput.drilling_costs],\n                    \'Capex_TTES\': [CapTT * userinput.Capex_TTES],\n                }, index = time_index_H)\n\n                \n                for k, v in obj_sol.items():\n                    system_info[k] = v\n\n                # Concatenate both DataFrames horizontally\n                df_result = pd.concat([heat_demand, m_solution, m_dual, system_info], axis=1)\n                df_result.reset_index(inplace=True)\n                df_result.rename(columns={\'index\': \'datetime\'}, inplace=True)\n\n                # Create filename with short variable names and values\n                if userinput.Depth_drilling_possible:\n                    filename = f"optimization_2_results_capmax_depth/phi_c_{round(phi_c,6)}_elp_{round(elpr,2)}_drc_{round(drc * userinput.drilling_costs,2)}_CapTT_{round(CapTT * userinput.Capex_TTES,2)}.csv"\n                else:\n                    filename = f"optimization_2_results_capmax/phi_c_{round(phi_c,6)}_elp_{round(elpr,2)}_drc_{round(drc * userinput.drilling_costs,2)}_CapTT_{round(CapTT * userinput.Capex_TTES,2)}.csv"\n                df_result.to_csv(filename, index=False)\n\n\nclear_output()\n'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'id': '0e937a0f',
#    'metadata': {'execution': {'iopub.status.busy': '2025-09-02T14:10:06.756980Z',
#      'iopub.execute_input': '2025-09-02T14:10:06.756980Z',
#      'iopub.status.idle': '2025-09-02T14:10:07.180089Z',
#      'shell.execute_reply': '2025-09-02T14:10:07.180089Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '<Axes: >'},
#      'execution_count': 5},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'elec_price_var = electricity_price + (electricity_price-electricity_price.mean()) * 1\nelec_price_var = elec_price_var.rolling(window=24*15, center=True, min_periods=1).mean()\nelec_price_var.plot()'}],
#  'metadata': {'kernelspec': {'display_name': 'esm-2023',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.3',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'}},
#  'nbformat': 4,
#  'nbformat_minor': 5}
